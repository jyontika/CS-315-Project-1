# %% [markdown]
# ## **Bar Plots CS315**
# ##### @author: Jyontika Kapoor
#
# In this notebook, I use the getDataFrames.py function to import three data frame based on our group's data. Then, I make bar plots to explore the data.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import getDataFrames
import matplotlib.colors as mcolors
from wordcloud import WordCloud

# %% [markdown]
# ### **Exploratory Data Analysis**

# %%
getDataFrames.df_control.head() #control data frame
# Out:
#    batch  index                                            music  \
# 0      1      0                               son original - 💐𝐵🪐
# 1      1      1                               I Wouldnt Mind - ♱
# 2      1      2                    som original - Gustavo Bonfim
# 3      1      3                    som original - Raphaela Diniz
# 4      1      4  Suara Seram Sangat Mencekam - Kholil Buitenzorg
#
#                                              hashtag               author  \
# 0                                                NaN          brookemonk_
# 1  christiantiktok, christianhumor, christianjoke...        dangmattsmith
# 2                                           tutorial           gus_bonfim
# 3               vaiprofycaramba, viral, fyp%E3%82%B7       raphaela_diniz
# 4  randomfacts, facts, curiosity, knowledge, didy...  __.random.facts.___
#
#      likes  comments  shares  saves collectionTime  \
# 0  3500000      6249  163400   8348    02-17-21-37
# 1   163700      2906   21200    687    02-17-21-37
# 2   539900      1291  112600   3800    02-17-21-37
# 3   370900      2633   20400    773    02-17-21-37
# 4     2974      3118     550  10300    02-17-21-37
#
#                                               postID
# 0                     son original - 💐𝐵🪐_brookemonk_
# 1                   I Wouldnt Mind - ♱_dangmattsmith
# 2           som original - Gustavo Bonfim_gus_bonfim
# 3       som original - Raphaela Diniz_raphaela_diniz
# 4  Suara Seram Sangat Mencekam - Kholil Buitenzor...

# %%
getDataFrames.df_control.shape
# Out:
# (15761, 11)

# %%
getDataFrames.df_save.head() #treatment data frame
# Out:
#    batch  index                           music  \
# 0      1      0           original sound - ESPN
# 1      1      1  I Have No Enemies - ★DGK132105
# 2      1      2               Asn - thsituan._.
# 3      1      3      Like That Sped Up - Laila!
# 4      1      4          original sound - Funny
#
#                                              hashtag      author    likes  \
# 0                             @wendy.bri, snow, cold        espn  2000000
# 1  @asianjeffontop, toastyog, streamer, fortnite,...    toasty1k    51200
# 2                                                NaN     ccabots   203000
# 3                           @bareandneutral, ingrown  dermdoctor   357800
# 4                                                NaN    baby_ok7  3100000
#
#    comments  shares   saves collectionTime  \
# 0     19900  170800  108600    02-14-16-57
# 1       441    3322      59    02-14-16-57
# 2      4712  124700    3817    02-14-16-57
# 3       561   11300    2068    02-14-16-57
# 4     34500  378200   81300    02-14-16-57
#
#                                     postID
# 0               original sound - ESPN_espn
# 1  I Have No Enemies - ★DGK132105_toasty1k
# 2                Asn - thsituan._._ccabots
# 3    Like That Sped Up - Laila!_dermdoctor
# 4          original sound - Funny_baby_ok7

# %%
getDataFrames.df_save.shape
# Out:
# (14840, 11)

# %%
getDataFrames.df_all.head()
# Out:
#    batch  index                           music  \
# 0      1      0           original sound - ESPN
# 1      1      1  I Have No Enemies - ★DGK132105
# 2      1      2               Asn - thsituan._.
# 3      1      3      Like That Sped Up - Laila!
# 4      1      4          original sound - Funny
#
#                                              hashtag      author    likes  \
# 0                             @wendy.bri, snow, cold        espn  2000000
# 1  @asianjeffontop, toastyog, streamer, fortnite,...    toasty1k    51200
# 2                                                NaN     ccabots   203000
# 3                           @bareandneutral, ingrown  dermdoctor   357800
# 4                                                NaN    baby_ok7  3100000
#
#    comments  shares   saves collectionTime  \
# 0     19900  170800  108600    02-14-16-57
# 1       441    3322      59    02-14-16-57
# 2      4712  124700    3817    02-14-16-57
# 3       561   11300    2068    02-14-16-57
# 4     34500  378200   81300    02-14-16-57
#
#                                     postID
# 0               original sound - ESPN_espn
# 1  I Have No Enemies - ★DGK132105_toasty1k
# 2                Asn - thsituan._._ccabots
# 3    Like That Sped Up - Laila!_dermdoctor
# 4          original sound - Funny_baby_ok7

# %%
getDataFrames.df_all.shape #ALL data frame
# Out:
# (30601, 11)

# %% [markdown]
# ### Author Bar Plot

# %%
author_counts = getDataFrames.df_all['author'].value_counts()
author_counts
# Out:
# author
# keemokazi             180
# lala_sadii            151
# krissleos             127
# grace.mitscherlich    123
# jackdoherty           122
#                      ...
# geo.gallagher           1
# talent.show49           1
# nnsquad4                1
# allison_heeren          1
# juyoungkang             1
# Name: count, Length: 9759, dtype: int64

# %%
active_author_counts = getDataFrames.df_save['author'].value_counts()
active_author_counts
# Out:
# author
# keemokazi         97
# lala_sadii        77
# jackdoherty       66
# infamous_wu13     62
# diamantblazi      60
#                   ..
# max._knight        1
# bapeanutbutter     1
# laurynandsteph     1
# donyamaa           1
# wenonugget         1
# Name: count, Length: 6140, dtype: int64

# %%
control_author_counts = getDataFrames.df_control['author'].value_counts()
control_author_counts
# Out:
# author
# keemokazi             83
# lala_sadii            74
# krissleos             69
# grace.mitscherlich    69
# skyyjade              57
#                       ..
# roknowswrestling       1
# condsty                1
# jumpersrecall          1
# ilovejesus9359         1
# juyoungkang            1
# Name: count, Length: 6985, dtype: int64

# %%
custom_color = mcolors.CSS4_COLORS['darkseagreen']
custom_font = {'fontname': 'Georgia'}

top_n = 15  
top_author_counts = author_counts.nlargest(top_n)

plt.figure(figsize=(10, 6))
top_author_counts.plot(kind='bar', color=custom_color)
plt.title(f'Top {top_n} Authors by Frequency', **custom_font)
plt.xlabel('Author', **custom_font)
plt.ylabel('Frequency', **custom_font)
plt.xticks(rotation=45, ha='right', **custom_font)
plt.yticks(**custom_font)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.DataFrame({'control_counts': control_author_counts, 'active_counts': active_author_counts})

# Calculate the total counts for each author
df['total_counts'] = df['control_counts'] + df['active_counts']

# Sort the DataFrame based on total counts in descending order
df_sorted = df.sort_values(by='total_counts', ascending=False).head(15)

# Set font to Georgia
plt.rcParams['font.family'] = 'Georgia'

# Plot a stacked bar chart for the top 15 authors
plt.figure(figsize=(10, 6))
df_sorted[['control_counts', 'active_counts']].plot(kind='bar', stacked=True, color=['purple', 'darkseagreen'])

plt.title('Top 15 Authors - Stacked Bar Chart')
plt.xlabel('Authors')
plt.ylabel('Counts')
plt.legend(title='Type', bbox_to_anchor=(0.7, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Hashtags - all

# %%
#drop NAs, split ",", transform to series, get value counts

hashtag_counts = getDataFrames.df_all['hashtag'].dropna().str.split(', ').explode().value_counts()

hashtag_counts
# Out:
# hashtag
# fyp                        9030
# foryou                     3659
# viral                      3642
# fyp%E3%82%B7               1975
# foryoupage                 1876
#                            ...
# brightonbeach                 1
# russianaccent                 1
# altmakeup                     1
# @catguylover72                1
# @i_like_watching_people       1
# Name: count, Length: 21856, dtype: int64

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(hashtag_counts)

colormap = 'plasma'

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
print(hashtag_counts.head(15))
# Out:
# hashtag
# fyp                           9030
# foryou                        3659
# viral                         3642
# fyp%E3%82%B7                  1975
# foryoupage                    1876
# funny                         1537
# trending                      1070
# tiktok                         780
# relatable                      733
# fyp%E3%82%B7%E3%82%9Aviral     675
# couple                         606
# viralvideo                     550
# trend                          536
# fy                             466
# love                           429
# Name: count, dtype: int64

# %% [markdown]
# ### Hashtags- Control

# %%
#drop NAs, split ",", transform to series, get value counts

hashtag_control = getDataFrames.df_control['hashtag'].dropna().str.split(', ').explode().value_counts()

hashtag_control
# Out:
# hashtag
# fyp                        4587
# foryou                     1877
# viral                      1787
# fyp%E3%82%B7               1000
# foryoupage                  925
#                            ...
# choirteacher                  1
# choir                         1
# singoff                       1
# rockingchair                  1
# @i_like_watching_people       1
# Name: count, Length: 16454, dtype: int64

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(hashtag_control)

colormap = 'plasma'

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
control_head = hashtag_control.head(15)

# %% [markdown]
# ### Hashtags active

# %%
#drop NAs, split ",", transform to series, get value counts

hashtag_active = getDataFrames.df_save['hashtag'].dropna().str.split(', ').explode().value_counts()

hashtag_active
# Out:
# hashtag
# fyp                                           4443
# viral                                         1855
# foryou                                        1782
# fyp%E3%82%B7                                   975
# foryoupage                                     951
#                                               ...
# tsquad%E2%9D%A4%EF%B8%8F%E2%9D%A4%EF%B8%8F       1
# @maccosmetics                                    1
# iwillbeatthis                                    1
# cancertok                                        1
# @therealomegapumpkin                             1
# Name: count, Length: 14129, dtype: int64

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(hashtag_active)

colormap = 'plasma'

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
active_head = hashtag_active.head(15)

# %%
import matplotlib.pyplot as plt
import numpy as np

hashtag_labels = active_head.index

# Set the bar height and position
bar_height = 0.35
bar_positions_active = np.arange(len(hashtag_labels))
bar_positions_control = bar_positions_active + bar_height

# Create the grouped bar chart
plt.figure(figsize=(6, 6))

plt.barh(bar_positions_active, active_head.values, height=bar_height, color='darkseagreen', label='Active Group')
plt.barh(bar_positions_control, control_head.values, height=bar_height, color='purple', label='Control Group')


plt.ylabel('Hashtags', fontname='Georgia')
plt.xlabel('Frequency', fontname='Georgia')
plt.title('Comparison of Top 15 Hashtag Frequencies between Active and Control Groups', fontname='Georgia')
plt.yticks(bar_positions_active + bar_height / 2, hashtag_labels, fontname='Georgia')
plt.legend()
plt.show()

# %%
control_head
# Out:
# hashtag
# fyp                           4587
# foryou                        1877
# viral                         1787
# fyp%E3%82%B7                  1000
# foryoupage                     925
# funny                          739
# trending                       563
# tiktok                         427
# relatable                      343
# fyp%E3%82%B7%E3%82%9Aviral     326
# couple                         297
# trend                          287
# fy                             279
# viralvideo                     273
# love                           215
# Name: count, dtype: int64

# %%
active_head
# Out:
# hashtag
# fyp                           4443
# viral                         1855
# foryou                        1782
# fyp%E3%82%B7                   975
# foryoupage                     951
# funny                          798
# trending                       507
# relatable                      390
# tiktok                         353
# fyp%E3%82%B7%E3%82%9Aviral     349
# couple                         309
# viralvideo                     277
# trend                          249
# comedy                         235
# love                           214
# Name: count, dtype: int64

# %% [markdown]
# ## Summary Stats

# %%
# Group by batch index (did not include in paper)
#grouped = df_all.groupby(["collectionTime", "testType"])

# Calculate summary statistics
summary_stats = getDataFrames.df_all.agg({
    "likes": ["mean", "median", "std", "min", "max"],
    "comments": ["mean", "median", "std", "min", "max"],
    "shares": ["mean", "median", "std", "min", "max"],
    "saves": ["mean", "median", "std", "min", "max"]
})

print("Summary Statistics for Numerical Variables:")
print(summary_stats)
# Out:
# Summary Statistics for Numerical Variables:
#                likes       comments        shares         saves
# mean    6.210345e+05    6844.914120  5.454501e+04  1.498964e+04
# median  1.588000e+05    1351.000000  1.380000e+04  1.329000e+03
# std     1.431519e+06   19973.567861  1.294201e+05  4.950547e+04
# min     0.000000e+00       0.000000  0.000000e+00  0.000000e+00
# max     2.630000e+07  494600.000000  2.800000e+06  1.700000e+06

# %%
summary_stats.loc['mean'].plot(kind='bar', title='Average Values for Popularity Measures')
# Out:
# <Axes: title={'center': 'Average Values for Popularity Measures'}>

# %%
mean_values = summary_stats.loc['mean']
median_values = summary_stats.loc['median']

mean_color = 'lightblue'
median_color = 'lightgreen'

bar_width = 0.35

mean_values.plot(kind='bar', color=mean_color, width=bar_width, position=0, label='Mean')

median_values.plot(kind='bar', color=median_color, width=bar_width, position=1, label='Median')

plt.title('Mean and Median Values for Popularity Measures')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
std_values = summary_stats.loc['std']

ax = std_values.plot(kind='bar', title='Standard Deviation Values of Variables of Interest', color='lightblue')


ax.get_yaxis().get_major_formatter().set_scientific(False)


plt.show()
